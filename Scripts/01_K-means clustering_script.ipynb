# %% [markdown]
# # Load libraries

# %%
pip install -r https://github.com/corinef/Automated-root-classification/blob/main/requirements.txt

# %%
import os
import re
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
from spectral import envi, imshow, kmeans
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %% [markdown]
# Insert name of folder containing data_files and scripts here

# %%
folder = ''

# %%
data_path = Path(folder)

data_files = 'Data_files'
data_files_path = data_path / data_files

# %% [markdown]
# ### Set results path

# %%
# Change the current working directory to the results_path
results_folder = 'Data_classification_results/KMeans data'
results_path = data_path / results_folder
results_path.mkdir(parents=True, exist_ok = True)
os.chdir(results_path)

# %% [markdown]
# ### Processing functions

# %%
def process_hdr_files(data_path):
    data = {}
    
    hdr_files = [x for x in data_files_path.iterdir() if x.suffix == '.hdr' and any(suffix in x.stem for suffix in ['_processed'])]
    
    for hdr_file in tqdm(hdr_files):
        name = " ".join(re.findall('(.*?)\_processed', hdr_file.stem))

        try:
            X = envi.open(hdr_file.as_posix()).load()
            cleaned_X = np.where(X > 1, 0, X.copy())

            data[name] = cleaned_X
            
        except Exception as e:
            print(f"Error while loading data from '{hdr_file}': {e}")

    return data

# %% [markdown]
# ### Process data

# %%
# Call the function to process the '.hdr' files and populate the data dictionary
data = process_hdr_files(data_path)
# Out:
# 100%|██████████| 2/2 [00:09<00:00,  4.81s/it]

# %%
data.keys()
# Out:
# dict_keys(['A2', 'D2'])

# %% [markdown]
# ### Load one file for metadata and wavelengths

# %%
def get_wl(data_path):
    
    hdr_files = [x for x in data_files_path.iterdir() if x.suffix == '.hdr' and x.stem.endswith('_processed')]

    for file in hdr_files:
        data_file = envi.open(file.as_posix()).load()
        break

    wl_list = np.array(data_file.metadata['wavelength'])
    wl = np.array([float(wavelength) for wavelength in wl_list])
    del data_file
    
    return wl

# %%
wl = get_wl(data_path)

# %%
print(wl)
# Out:
# [470.        472.885906  475.7718121 478.6577181 481.5436242 484.4295302
#  487.3154362 490.2013423 493.0872483 495.9731544 498.8590604 501.7449664
#  504.6308725 507.5167785 510.4026846 513.2885906 516.1744966 519.0604027
#  521.9463087 524.8322148 527.7181208 530.6040268 533.4899329 536.3758389
#  539.261745  542.147651  545.033557  547.9194631 550.8053691 553.6912752
#  556.5771812 559.4630872 562.3489933 565.2348993 568.1208054 571.0067114
#  573.8926174 576.7785235 579.6644295 582.5503356 585.4362416 588.3221477
#  591.2080537 594.0939597 596.9798658 599.8657718 602.7516779 605.6375839
#  608.5234899 611.409396  614.295302  617.1812081 620.0671141 622.9530201
#  625.8389262 628.7248322 631.6107383 634.4966443 637.3825503 640.2684564
#  643.1543624 646.0402685 648.9261745 651.8120805 654.6979866 657.5838926
#  660.4697987 663.3557047 666.2416107 669.1275168 672.0134228 674.8993289
#  677.7852349 680.6711409 683.557047  686.442953  689.3288591 692.2147651
#  695.1006711 697.9865772 700.8724832 703.7583893 706.6442953 709.5302013
#  712.4161074 715.3020134 718.1879195 721.0738255 723.9597315 726.8456376
#  729.7315436 732.6174497 735.5033557 738.3892617 741.2751678 744.1610738
#  747.0469799 749.9328859 752.8187919 755.704698  758.590604  761.4765101
#  764.3624161 767.2483221 770.1342282 773.0201342 775.9060403 778.7919463
#  781.6778523 784.5637584 787.4496644 790.3355705 793.2214765 796.1073826
#  798.9932886 801.8791946 804.7651007 807.6510067 810.5369128 813.4228188
#  816.3087248 819.1946309 822.0805369 824.966443  827.852349  830.738255
#  833.6241611 836.5100671 839.3959732 842.2818792 845.1677852 848.0536913
#  850.9395973 853.8255034 856.7114094 859.5973154 862.4832215 865.3691275
#  868.2550336 871.1409396 874.0268456 876.9127517 879.7986577 882.6845638
#  885.5704698 888.4563758 891.3422819 894.2281879 897.114094  900.       ]

# %% [markdown]
# # Pre-processing with KMeans<a class="anchor" id="kmeans"></a>

# %% [markdown]
# Run each K-means with 3 clusters and 20 iterations
#
#     1. Convert all K-Means Spectra to one dataframe with correct labels
#
#     2. Export dataframe to excel
#
# Show the K-means class images
#
#     -  Save as .PNG file

# %%
def run_kmeans(data, num_clusters, num_iterations):
    '''Example usage:
    Assuming you have a dictionary called 'data':
    data = {'key1': data1, 'key2': data2, ...}
    run_kmeans(data, num_clusters=3, num_iterations=20)'''

    results_dict = {}
    
    for x in tqdm(data.keys()):
            print(x)
            result = kmeans(data[x], num_clusters, num_iterations)
            
            results_dict[f"kmeans_img_{x}"] = result[0]
            
            results_dict[f"kmeans_spectra_{x}"] = pd.DataFrame(result[1], columns = wl, index = k_index)

    return results_dict

# %%
k_index = ['1', '2', '3'] 

all_kmeans = run_kmeans(data, num_clusters = 3, num_iterations = 20)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# A2
# spectral:INFO: k-means iteration 1 - 626102 pixels reassigned.
# spectral:INFO: k-means iteration 2 - 69754 pixels reassigned.
# spectral:INFO: k-means iteration 3 - 47047 pixels reassigned.
# spectral:INFO: k-means iteration 4 - 68560 pixels reassigned.
# spectral:INFO: k-means iteration 5 - 72704 pixels reassigned.
# spectral:INFO: k-means iteration 6 - 69711 pixels reassigned.
# spectral:INFO: k-means iteration 7 - 64478 pixels reassigned.
# spectral:INFO: k-means iteration 8 - 58730 pixels reassigned.
# spectral:INFO: k-means iteration 9 - 52608 pixels reassigned.
# spectral:INFO: k-means iteration 10 - 47008 pixels reassigned.
# spectral:INFO: k-means iteration 11 - 41412 pixels reassigned.
# spectral:INFO: k-means iteration 12 - 35983 pixels reassigned.
# spectral:INFO: k-means iteration 13 - 30671 pixels reassigned.
# spectral:INFO: k-means iteration 14 - 25870 pixels reassigned.
# spectral:INFO: k-means iteration 15 - 21942 pixels reassigned.
# spectral:INFO: k-means iteration 16 - 18561 pixels reassigned.
# spectral:INFO: k-means iteration 17 - 15539 pixels reassigned.
# spectral:INFO: k-means iteration 18 - 12899 pixels reassigned.
# spectral:INFO: k-means iteration 19 - 10699 pixels reassigned.
# spectral:INFO: k-means iteration 20 - 8745 pixels reassigned.
# spectral:INFO: kmeans terminated with 3 clusters after 20 iterations.
#  50%|█████     | 1/2 [01:12<01:12, 72.25s/it]
# D2
# spectral:INFO: k-means iteration 1 - 63327 pixels reassigned.
# spectral:INFO: k-means iteration 2 - 10177 pixels reassigned.
# spectral:INFO: k-means iteration 3 - 12986 pixels reassigned.
# spectral:INFO: k-means iteration 4 - 26940 pixels reassigned.
# spectral:INFO: k-means iteration 5 - 51104 pixels reassigned.
# spectral:INFO: k-means iteration 6 - 91458 pixels reassigned.
# spectral:INFO: k-means iteration 7 - 141309 pixels reassigned.
# spectral:INFO: k-means iteration 8 - 182011 pixels reassigned.
# spectral:INFO: k-means iteration 9 - 190392 pixels reassigned.
# spectral:INFO: k-means iteration 10 - 168819 pixels reassigned.
# spectral:INFO: k-means iteration 11 - 134416 pixels reassigned.
# spectral:INFO: k-means iteration 12 - 101101 pixels reassigned.
# spectral:INFO: k-means iteration 13 - 73148 pixels reassigned.
# spectral:INFO: k-means iteration 14 - 51869 pixels reassigned.
# spectral:INFO: k-means iteration 15 - 36395 pixels reassigned.
# spectral:INFO: k-means iteration 16 - 25404 pixels reassigned.
# spectral:INFO: k-means iteration 17 - 17604 pixels reassigned.
# spectral:INFO: k-means iteration 18 - 12268 pixels reassigned.
# spectral:INFO: k-means iteration 19 - 8409 pixels reassigned.
# spectral:INFO: k-means iteration 20 - 5828 pixels reassigned.
# spectral:INFO: kmeans terminated with 3 clusters after 20 iterations.
# 100%|██████████| 2/2 [02:24<00:00, 72.42s/it]

# %%
all_kmeans.keys()
# Out:
# dict_keys(['kmeans_img_A2', 'kmeans_spectra_A2', 'kmeans_img_D2', 'kmeans_spectra_D2'])

# %%
all_kmeans['kmeans_spectra_A2']
# Out:
#    470.000000  472.885906  475.771812  478.657718  481.543624  484.429530  \
# 1    0.061338    0.061254    0.059574    0.058025    0.056806    0.056754
# 2    0.153077    0.153369    0.151087    0.149361    0.148657    0.149288
# 3    0.323643    0.323930    0.320425    0.318705    0.319375    0.321596
#
#    487.315436  490.201342  493.087248  495.973154  ...  874.026846  \
# 1    0.058234    0.056709    0.055121    0.053163  ...    0.158653
# 2    0.151144    0.150332    0.149569    0.148828  ...    0.312734
# 3    0.324095    0.324095    0.324723    0.326374  ...    0.532199
#
#    876.912752  879.798658  882.684564  885.570470  888.456376  891.342282  \
# 1    0.160488    0.162443    0.164511    0.166369    0.168284    0.170045
# 2    0.314156    0.315511    0.316741    0.317716    0.318706    0.319530
# 3    0.532583    0.532808    0.532669    0.532146    0.531469    0.530619
#
#    894.228188  897.114094  900.000000
# 1    0.171925    0.172775    0.172775
# 2    0.320536    0.321034    0.321034
# 3    0.530017    0.529852    0.529852
#
# [3 rows x 150 columns]

# %% [markdown]
# ## Training spectra dataframe<a class="anchor" id="training_df"></a>

# %%
all_kmeans_data = pd.DataFrame()

for key, item in all_kmeans.items():
    if 'spectra' in key:
        
        t = " ".join(re.findall('kmeans_spectra_(.*)', key))
        temp_df = all_kmeans[key].copy()
        temp_df['Species'] = t
        
        temp_df.reset_index(inplace = True)
        temp_df.rename(columns = {'index' : 'Class'}, inplace = True)
        temp_df.set_index(['Class', 'Species'], inplace = True)
        
        all_kmeans_data = pd.concat([all_kmeans_data, temp_df])

all_kmeans_data.to_excel('kmeans_data.xlsx')

# %%
all_kmeans_data
# Out:
#                                                                        470.000000  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.061338
# 2     A2      1         40  f11       1              1                   0.153077
# 3     A2      1         40  f11       1              1                   0.323643
# 1     D2      1         40  f11       2              1                   0.034746
# 2     D2      1         40  f11       2              1                   0.052583
# 3     D2      1         40  f11       2              1                   0.183949
#
#                                                                        472.885906  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.061254
# 2     A2      1         40  f11       1              1                   0.153369
# 3     A2      1         40  f11       1              1                   0.323930
# 1     D2      1         40  f11       2              1                   0.034982
# 2     D2      1         40  f11       2              1                   0.052743
# 3     D2      1         40  f11       2              1                   0.184184
#
#                                                                        475.771812  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.059574
# 2     A2      1         40  f11       1              1                   0.151087
# 3     A2      1         40  f11       1              1                   0.320425
# 1     D2      1         40  f11       2              1                   0.033824
# 2     D2      1         40  f11       2              1                   0.050775
# 3     D2      1         40  f11       2              1                   0.181188
#
#                                                                        478.657718  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.058025
# 2     A2      1         40  f11       1              1                   0.149361
# 3     A2      1         40  f11       1              1                   0.318705
# 1     D2      1         40  f11       2              1                   0.032761
# 2     D2      1         40  f11       2              1                   0.048993
# 3     D2      1         40  f11       2              1                   0.179525
#
#                                                                        481.543624  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.056806
# 2     A2      1         40  f11       1              1                   0.148657
# 3     A2      1         40  f11       1              1                   0.319375
# 1     D2      1         40  f11       2              1                   0.032229
# 2     D2      1         40  f11       2              1                   0.048145
# 3     D2      1         40  f11       2              1                   0.179744
#
#                                                                        484.429530  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.056754
# 2     A2      1         40  f11       1              1                   0.149288
# 3     A2      1         40  f11       1              1                   0.321596
# 1     D2      1         40  f11       2              1                   0.033073
# 2     D2      1         40  f11       2              1                   0.049030
# 3     D2      1         40  f11       2              1                   0.181277
#
#                                                                        487.315436  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.058234
# 2     A2      1         40  f11       1              1                   0.151144
# 3     A2      1         40  f11       1              1                   0.324095
# 1     D2      1         40  f11       2              1                   0.034601
# 2     D2      1         40  f11       2              1                   0.050414
# 3     D2      1         40  f11       2              1                   0.182725
#
#                                                                        490.201342  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.056709
# 2     A2      1         40  f11       1              1                   0.150332
# 3     A2      1         40  f11       1              1                   0.324095
# 1     D2      1         40  f11       2              1                   0.033345
# 2     D2      1         40  f11       2              1                   0.048865
# 3     D2      1         40  f11       2              1                   0.181675
#
#                                                                        493.087248  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.055121
# 2     A2      1         40  f11       1              1                   0.149569
# 3     A2      1         40  f11       1              1                   0.324723
# 1     D2      1         40  f11       2              1                   0.032017
# 2     D2      1         40  f11       2              1                   0.047481
# 3     D2      1         40  f11       2              1                   0.181109
#
#                                                                        495.973154  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.053163
# 2     A2      1         40  f11       1              1                   0.148828
# 3     A2      1         40  f11       1              1                   0.326374
# 1     D2      1         40  f11       2              1                   0.030329
# 2     D2      1         40  f11       2              1                   0.046036
# 3     D2      1         40  f11       2              1                   0.181140
#
#                                                                        ...  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups  ...
# 1     A2      1         40  f11       1              1                 ...
# 2     A2      1         40  f11       1              1                 ...
# 3     A2      1         40  f11       1              1                 ...
# 1     D2      1         40  f11       2              1                 ...
# 2     D2      1         40  f11       2              1                 ...
# 3     D2      1         40  f11       2              1                 ...
#
#                                                                        874.026846  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.158653
# 2     A2      1         40  f11       1              1                   0.312734
# 3     A2      1         40  f11       1              1                   0.532199
# 1     D2      1         40  f11       2              1                   0.089530
# 2     D2      1         40  f11       2              1                   0.173969
# 3     D2      1         40  f11       2              1                   0.350809
#
#                                                                        876.912752  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.160488
# 2     A2      1         40  f11       1              1                   0.314156
# 3     A2      1         40  f11       1              1                   0.532583
# 1     D2      1         40  f11       2              1                   0.091078
# 2     D2      1         40  f11       2              1                   0.176027
# 3     D2      1         40  f11       2              1                   0.351890
#
#                                                                        879.798658  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.162443
# 2     A2      1         40  f11       1              1                   0.315511
# 3     A2      1         40  f11       1              1                   0.532808
# 1     D2      1         40  f11       2              1                   0.092743
# 2     D2      1         40  f11       2              1                   0.178144
# 3     D2      1         40  f11       2              1                   0.352825
#
#                                                                        882.684564  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.164511
# 2     A2      1         40  f11       1              1                   0.316741
# 3     A2      1         40  f11       1              1                   0.532669
# 1     D2      1         40  f11       2              1                   0.094471
# 2     D2      1         40  f11       2              1                   0.180264
# 3     D2      1         40  f11       2              1                   0.353542
#
#                                                                        885.570470  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.166369
# 2     A2      1         40  f11       1              1                   0.317716
# 3     A2      1         40  f11       1              1                   0.532146
# 1     D2      1         40  f11       2              1                   0.096128
# 2     D2      1         40  f11       2              1                   0.182202
# 3     D2      1         40  f11       2              1                   0.353946
#
#                                                                        888.456376  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.168284
# 2     A2      1         40  f11       1              1                   0.318706
# 3     A2      1         40  f11       1              1                   0.531469
# 1     D2      1         40  f11       2              1                   0.097807
# 2     D2      1         40  f11       2              1                   0.184132
# 3     D2      1         40  f11       2              1                   0.354262
#
#                                                                        891.342282  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.170045
# 2     A2      1         40  f11       1              1                   0.319530
# 3     A2      1         40  f11       1              1                   0.530619
# 1     D2      1         40  f11       2              1                   0.099260
# 2     D2      1         40  f11       2              1                   0.185810
# 3     D2      1         40  f11       2              1                   0.354422
#
#                                                                        894.228188  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.171925
# 2     A2      1         40  f11       1              1                   0.320536
# 3     A2      1         40  f11       1              1                   0.530017
# 1     D2      1         40  f11       2              1                   0.100929
# 2     D2      1         40  f11       2              1                   0.187686
# 3     D2      1         40  f11       2              1                   0.354926
#
#                                                                        897.114094  \
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.172775
# 2     A2      1         40  f11       1              1                   0.321034
# 3     A2      1         40  f11       1              1                   0.529852
# 1     D2      1         40  f11       2              1                   0.101721
# 2     D2      1         40  f11       2              1                   0.188546
# 3     D2      1         40  f11       2              1                   0.355201
#
#                                                                        900.000000
# Class Species Replicate Day Treatment Species_Groups Treatment_Groups
# 1     A2      1         40  f11       1              1                   0.172775
# 2     A2      1         40  f11       1              1                   0.321034
# 3     A2      1         40  f11       1              1                   0.529852
# 1     D2      1         40  f11       2              1                   0.101721
# 2     D2      1         40  f11       2              1                   0.188546
# 3     D2      1         40  f11       2              1                   0.355201
#
# [6 rows x 150 columns]

# %% [markdown]
# ## KMeans class data<a class="anchor" id="class_data"></a>

# %%
for key, item in all_kmeans.items():
    if 'img' in key:
        df = pd.DataFrame(item)
        df.to_csv(key + '.csv')

# %% [markdown]
# ## Show KMeans classes<a class="anchor" id="show_classes"></a>

# %%
for key, item in all_kmeans.items():
    if 'img' in key:
        imshow(classes = item, colors = [(0, 0, 0), (212, 17, 89), (255, 215, 0)])
        plt.axis('off')
        plt.savefig(key + '.png', dpi=300, bbox_inches='tight')
        plt.close()
